# %% [markdown]
# <a href="https://colab.research.google.com/github/Arka1212/Data-Science-Assignments/blob/main/Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Consider following code to answer further questions:
# # import pandas as pd
# # course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
# # duration = [2,3,6,4]
# # df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ # : # duration})

# %%
# Creating the above dataframe.
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name': course_name, 'duration': duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# # **Q1. Write a code to print the data present in the second row of the dataframe, df.**

# %%
# Code
n_df = pd.DataFrame(df.iloc[1])
n_df.T
# Out:
#         course_name duration
# 1  Machine Learning        3

# %% [markdown]
# # **Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?**

# %%
'''
loc selects rows based on names of columns and index doesnt work here as upperbound is not silent here whereas iloc works based on index
rule as upperbound is silent here and it cant work with coilumn name rather it needs column number.
'''
# Out:
# '\nloc selects rows based on names of columns and index doesnt work here as upperbound is not silent here whereas iloc works based on index\nrule as upperbound is silent here and it cant work with coilumn name rather it needs column number.\n'

# %% [markdown]
# # **Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].**

# %%
# Re-indexing the above dataframe.
new_df = df.reindex([3,0,1,2])
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
# Finding specified outputs.
print(new_df.loc[2])
print(new_df.iloc[2])
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# **Simply loc selects the rows based on mathing index number mentioned such as 2 is mentioned, so it will output row which have index number 2 but iloc on the other hand outputs the row which has ranked 2 as index.**

# %% [markdown]
# # Consider the below code to answer further questions:
# # import pandas as pd
# # import numpy as np
# # columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
# # indices = [1,2,3,4,5,6]
# #Creating a dataframe:
# # df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
# Creating a new dataframe.
import pandas as pd
import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.069126  0.793321  0.449911  0.210051  0.507220  0.491225
# 2  0.738199  0.340892  0.013379  0.056094  0.825656  0.718939
# 3  0.076439  0.865611  0.125333  0.780300  0.637147  0.436904
# 4  0.582624  0.708467  0.414321  0.563995  0.297935  0.070373
# 5  0.632082  0.418852  0.438210  0.240984  0.142469  0.351232
# 6  0.521153  0.494751  0.779533  0.530873  0.502138  0.449898

# %% [markdown]
# # **Q4. Write a code to find the following statistical measurements for the above dataframe df1:**
# ## **(i) mean of each and every column present in the dataframe.**
# ## **(ii) standard deviation of column, ‘column_2’**

# %%
# Mean of all columns.
for i in df1.columns:
  print(f'Mean of {i}: {round(df1[i].mean(),4)}')
# Out:
# Mean of column_1: 0.4366
# Mean of column_2: 0.6036
# Mean of column_3: 0.3701
# Mean of column_4: 0.397
# Mean of column_5: 0.4854
# Mean of column_6: 0.4198

# %%
# Standard Deviation of column 2.
print(f"Standard Deviation of second column: {df1['column_2'].std()}")
# Out:
# Standard Deviation of second column: 0.21477247526516327

# %% [markdown]
# # **Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.**
#
# # If you are getting errors in executing it then explain why. [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
# Replacing data.
df2 = df1.copy()
df2.loc[:, ['column_2']] = 'DEMO'
df2
# Out:
#    column_1 column_2  column_3  column_4  column_5  column_6
# 1  0.069126     DEMO  0.449911  0.210051  0.507220  0.491225
# 2  0.738199     DEMO  0.013379  0.056094  0.825656  0.718939
# 3  0.076439     DEMO  0.125333  0.780300  0.637147  0.436904
# 4  0.582624     DEMO  0.414321  0.563995  0.297935  0.070373
# 5  0.632082     DEMO  0.438210  0.240984  0.142469  0.351232
# 6  0.521153     DEMO  0.779533  0.530873  0.502138  0.449898

# %% [markdown]
# **Now mean of the mean cannot be calculated for 'column_2' as it is an string datatype and mean can be only be calculated for numerical dataset. So, while trying to calculate mean of 'column_2', it will throw an error.**

# %% [markdown]
# # **Q6. What do you understand about the windows function in pandas and list the types of windows functions?**

# %%
'''
Windows function basically takes a window and calculates the aggregate function taking the number of data mentioned in window
and is basically used for time series data.
'''
# Out:
# '\nWindows function basically takes a window and calculates the aggregate function taking the number of data mentioned in window\nand is basically used for time series data.\n'

# %% [markdown]
# # **Q7. Write a code to print only the current month and year at the time of answering this question. [Hint: Use pandas.datetime function]**

# %%
# Code.
import datetime
current_date = datetime.datetime.now()
current_month = current_date.strftime('%B')
current_year = current_date.strftime('%Y')

print(f"Current month: {current_month}")
print(f"Current year: {current_year}")
# Out:
# Current month: September
# Current year: 2023

# %% [markdown]
# # **Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.**

# %%
# Input dates from the user
date1_str = input("Enter the first date (YYYY-MM-DD): ")
date2_str = input("Enter the second date (YYYY-MM-DD): ")

# Convert the input strings to datetime objects
date1 = pd.to_datetime(date1_str, format='%Y-%m-%d')
date2 = pd.to_datetime(date2_str, format='%Y-%m-%d')

# Calculate the time difference
time_diff = date2 - date1

# Extract days, hours, and minutes from the time difference
days = time_diff.days
hours, remainder = divmod(time_diff.seconds, 3600)
minutes, _ = divmod(remainder, 60)

# Display the result
print(f"Difference between the two dates:")
print(f"Days: {days} days")
print(f"Hours: {hours} hours")
print(f"Minutes: {minutes} minutes")
# Out:
# Enter the first date (YYYY-MM-DD): 1997-09-12
# Enter the second date (YYYY-MM-DD): 2005-12-11
# Difference between the two dates:
# Days: 3012 days
# Hours: 0 hours
# Minutes: 0 minutes

# %% [markdown]
# # **Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.**

# %%
# Prompt the user for the CSV file path
file_path = input("Enter the CSV file path: ")

# Read the CSV file into a DataFrame
try:
    df = pd.read_csv(file_path)
except FileNotFoundError:
    print("File not found. Please provide a valid file path.")
    exit()

# Display the available columns in the CSV file
print("Available columns in the CSV file:")
print(df.columns)

# Prompt the user for the column name to convert to categorical
column_name = input("Enter the column name to convert to categorical: ")

# Check if the specified column exists in the DataFrame
if column_name not in df.columns:
    print(f"Column '{column_name}' not found in the CSV file.")
    exit()

# Prompt the user for the category order
category_order = input("Enter the category order (comma-separated, e.g., 'Low,Medium,High'): ").split(',')

# Convert the specified column to categorical with the specified order
df[column_name] = pd.Categorical(df[column_name], categories=category_order, ordered=True)

# Sort the DataFrame based on the categorical column
sorted_df = df.sort_values(by=column_name)

# Display the sorted data
print("\nSorted Data:")
print(sorted_df)
# Out:
# Enter the CSV file path: /content/sample_data/california_housing_train.csv
# Available columns in the CSV file:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')
# Enter the column name to convert to categorical: total_rooms
# Enter the category order (comma-separated, e.g., 'Low,Medium,High'): comma-separated
#
# Sorted Data:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0         NaN          1283.0
# 1        -114.47     34.40                19.0         NaN          1901.0
# 2        -114.56     33.69                17.0         NaN           174.0
# 3        -114.57     33.64                14.0         NaN           337.0
# 4        -114.57     33.57                20.0         NaN           326.0
# ...
