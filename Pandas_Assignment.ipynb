# %% [markdown]
# <a href="https://colab.research.google.com/github/Arka1212/Data-Science-Assignments/blob/main/Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Consider following code to answer further questions:
# # import pandas as pd
# # course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
# # duration = [2,3,6,4]
# # df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ # : # duration})

# %%
# Creating the above dataframe.
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name': course_name, 'duration': duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# # **Q1. Write a code to print the data present in the second row of the dataframe, df.**

# %%
# Code
n_df = pd.DataFrame(df.iloc[1])
n_df.T
# Out:
#         course_name duration
# 1  Machine Learning        3

# %% [markdown]
# # **Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?**

# %%
'''
loc selects rows based on names of columns and index doesnt work here as upperbound is not silent here whereas iloc works based on index
rule as upperbound is silent here and it cant work with coilumn name rather it needs column number.
'''
# Out:
# '\nloc selects rows based on names of columns and index doesnt work here as upperbound is not silent here whereas iloc works based on index\nrule as upperbound is silent here and it cant work with coilumn name rather it needs column number.\n'

# %% [markdown]
# # **Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].**

# %%
# Re-indexing the above dataframe.
new_df = df.reindex([3,0,1,2])
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
# Finding specified outputs.
print(new_df.loc[2])
print(new_df.iloc[2])
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# **Simply loc selects the rows based on mathing index number mentioned such as 2 is mentioned, so it will output row which have index number 2 but iloc on the other hand outputs the row which has ranked 2 as index.**

# %% [markdown]
# # Consider the below code to answer further questions:
# # import pandas as pd
# # import numpy as np
# # columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
# # indices = [1,2,3,4,5,6]
# #Creating a dataframe:
# # df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
# Creating a new dataframe.
import pandas as pd
import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.703062  0.950937  0.325402  0.656713  0.335943  0.948214
# 2  0.156001  0.967435  0.702638  0.087287  0.774791  0.751305
# 3  0.693344  0.726692  0.922079  0.854500  0.297431  0.536788
# 4  0.948515  0.433387  0.622874  0.710942  0.239849  0.296310
# 5  0.614466  0.163925  0.882154  0.010961  0.684266  0.721111
# 6  0.390169  0.227337  0.822671  0.332271  0.018892  0.988271
